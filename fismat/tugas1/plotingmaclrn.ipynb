# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as smp
import scipy as scp
from numpy import *
from matplotlib import *
from sympy import *
from mpmath import *
from scipy import *
plt.style.use('classic')

# %% [markdown]
# 1
# $$x^2\ln{1-x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (x**2*len(1-x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 2
# $$x\sqrt{1+x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += x*np.sqrt(1+x)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\4173476544.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += x*np.sqrt(1+x)
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\4173476544.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += x*np.sqrt(1+x)
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\4173476544.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += x*np.sqrt(1+x)
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\4173476544.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += x*np.sqrt(1+x)

# %% [markdown]
# 3
# $$\frac{1}{x}\sin{x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += ((1/x)*np.sin(x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 4
# $$\frac{1}{\sqrt{1-x^2}}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (1/np.sqrt(1-x**2))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_21304\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))

# %% [markdown]
# 5
# $$\frac{1+x}{1-x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (1+x / 1-x)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 6
# $$\sin{x}^2$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.sin(x**2))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 7
# $$\frac{e^x}{1-x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.exp(x)/1-x)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 8
# $$e^x\sin{x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.exp(x)*np.sin(x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 9
# $$\ln{\frac{1+x}{1-x}}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (len(1+x / 1-x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 10
# $$\tan^2{x}$$

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.tan(x)**2)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
