# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as smp
from numpy import *
from matplotlib import *
from sympy import *
from mpmath import *

# %% [markdown]
# 1

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (x**2*np.log(1-x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1417158596.py:6: RuntimeWarning: invalid value encountered in log
#   y += (x**2*np.log(1-x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1417158596.py:6: RuntimeWarning: invalid value encountered in log
#   y += (x**2*np.log(1-x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1417158596.py:6: RuntimeWarning: invalid value encountered in log
#   y += (x**2*np.log(1-x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1417158596.py:6: RuntimeWarning: invalid value encountered in log
#   y += (x**2*np.log(1-x))

# %% [markdown]
# 2

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (x*np.sqrt(1+x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1264991622.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (x*np.sqrt(1+x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1264991622.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (x*np.sqrt(1+x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1264991622.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (x*np.sqrt(1+x))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\1264991622.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (x*np.sqrt(1+x))

# %% [markdown]
# 3

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (1/x*np.sin(x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 4

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (1/np.sqrt(1-x**2))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_320\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_320\27219751.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y += (1/np.sqrt(1-x**2))

# %% [markdown]
# 5

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (1+x / 1-x)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 6

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.sin(x**2))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 7

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.exp(x)/1-x)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 8

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.exp(x)*np.sin(x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 9

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.log(1+x / 1-x))
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# 10

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))
labels = ['S1', 'S2', 'S3', 'S4']
plt.figure()
for n, label in zip(range(4), labels):
    y += (np.tan(x)**2)
    plt.plot(x, y, label=label)
plt.plot(x, np.cos(x), 'k', label='Analytic')
plt.grid()
plt.title('Grafik deret maclaurin')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right', prop={'size': 10})
plt.show()
